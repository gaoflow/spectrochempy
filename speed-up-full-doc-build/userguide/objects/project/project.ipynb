# %% [markdown]
# # Project management
#
# from pathlib import Path

# %%
import spectrochempy as scp

# %% [markdown]
# ## Project creation
# We can easily create a new project to store various datasets

# %%
proj = scp.Project()

# %% [markdown]
# As we did not specify a name, a name has been attributed automatically:

# %%
proj.name
# Out:
# 'Project-Project_3176bc76'

# %% [markdown]
# ------
# To get the signature of the object, one can use the usual '?'. Uncomment the following line to check

# %%
# Project?

# %% [markdown]
# ----
# Let's change this name

# %%
proj.name = "myNMRdata"
proj
# Out:
# Project&nbsp;myNMRdata:<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;(empty&nbsp;project)

# %% [markdown]
# Now we will add a dataset to the project.
#
# First we read the dataset (here some NMR data) and we give it some name (e.g. 'nmr n°1').
#
# Requires the official ``spectrochempy-nmr`` plugin.
# Install with: ``pip install spectrochempy[nmr]``.

# %%
datadir = scp.pathclean(scp.preferences.datadir)
path = datadir / "nmrdata" / "bruker" / "tests" / "nmr"

nd1 = scp.nmr.read_topspin(
    path / "topspin_1d", expno=1, remove_digital_filter=True, name="NMR_1D"
)
# Use the same dataset twice for the example (real projects would use different data)
nd2 = nd1.copy()
nd2.name = "NMR_1D_copy"
# Out:
# <style>/* SpectroChemPy output styling */
# .scp-output {
#     display: flex;
#     flex-direction: column;
#     gap: 2px;
# }
#
# .scp-output details {
#     padding: 1px;
# }
#
# .scp-output summary {
#     cursor: pointer;
#     font-weight: normal;
#     /*bold;*/
#     font-size: 11pt;
# }
#
# .scp-output summary:hover {
#     color: #888;
# }
#
# /* Parameters display styling */
# .scp-output .section {
#     display: flex;
#     flex-direction: row;
#     gap: 2px;
#     font-family: Arial, sans-serif;
#     font-size: 10pt;
#     margin-left: 15px;
# }
#
# .scp-output .meta-name,
# .scp-output .attr-name {
#     font-weight: 500;
#     color: #28A745;
#     text-align: right;
# }
#
# .scp-output .attr-name {
#     min-width: 100px;
# }
#
# .scp-output .meta-name {
#     min-width: 150px;
# }
#
# .scp-output .meta-value,
# .scp-output .attr-value {
#     flex: 1;
# }
#
# .scp-output .numeric {
#     color: #2D7FF9;
#     margin-left: 120px;
#     font-size: 10pt;
# }
#
# .scp-output .label {
#     color: darkcyan;
#     margin-left: 120px;
#     font-size: 10pt;
# }
#
# .scp-output .attr-value .numeric {
#     color: #2D7FF9;
#     margin-left: 0px;
#     font-size: 10pt;
# }
#
# .scp-output .attr-value .label {
#     color: darkcyan;
#     margin-left: 0px;
#     font-size: 10pt;
# }
# </style>
#  WARNING | (UserWarning) No module named 'spectrochempy_hypercomplex'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 8
#       4 nd1 = scp.nmr.read_topspin(
#       5     path / "topspin_1d", expno=1, remove_digital_filter=True, name="NMR_1D"
#       6 )
#       7 # Use the same dataset twice for the example (real projects would use different data)
# ----> 8 nd2 = nd1.copy()
#       9 nd2.name = "NMR_1D_copy"
#
# AttributeError: 'NoneType' object has no attribute 'copy'

# %% [markdown]
# To add it to the project, we use the `add_dataset` function for a single dataset:

# %%
proj.add_datasets(nd1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 proj.add_datasets(nd1)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/core/project/project.py:436, in Project.add_datasets(self, *datasets)
#     411 """
#     412 Add several datasets to the current project.
#     413
#    (...)    433
#     434 """
#     435 for ds in datasets:
# --> 436     self.add_dataset(ds)
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/core/project/project.py:463, in Project.add_dataset(self, dataset, name)
#     438 def add_dataset(self, dataset, name=None):
#     439     """
#     440     Add a single dataset to the current project.
#     441
#    (...)    461
#     462     """
# --> 463     dataset.parent = self
#     464     if name is None:
#     465         name = dataset.name
#
# AttributeError: 'NoneType' object has no attribute 'parent' and no __dict__ for setting new attributes

# %% [markdown]
# or `add_datasets` for several datasets.

# %%
proj.add_datasets(nd1, nd2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 proj.add_datasets(nd1, nd2)
#
# NameError: name 'nd2' is not defined

# %% [markdown]
# Display its structure

# %%
proj
# Out:
# Project&nbsp;myNMRdata:<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;(empty&nbsp;project)

# %% [markdown]
# It is also possible to add other projects as sub-project (using the `add_project` )

# %% [markdown]
# ## Remove an element from a project

# %%
proj.remove_dataset("NMR_1D")
proj
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 proj.remove_dataset("NMR_1D")
#       2 proj
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/core/project/project.py:486, in Project.remove_dataset(self, name)
#     476 def remove_dataset(self, name):
#     477     """
#     478     Remove a dataset from the project.
#     479
#    (...)    484
#     485     """
# --> 486     self._datasets[name]._parent = None  # remove the parent info
#     487     del self._datasets[name]
#
# KeyError: 'NMR_1D'

# %% [markdown]
# ## Get project's elements

# %%
proj.add_datasets(nd1, nd2)
proj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 proj.add_datasets(nd1, nd2)
#       2 proj
#
# NameError: name 'nd2' is not defined

# %% [markdown]
# We can just use the name of the element as a project attribute.

# %%
proj.NMR_1D
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 proj.NMR_1D
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/core/project/project.py:198, in Project.__getattr__(self, item)
#     194 if item in self.meta:
#     195     # return the attribute
#     196     return self.meta[item]
# --> 198 raise AttributeError
#
# AttributeError:

# %%
_ = proj.NMR_1D.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 _ = proj.NMR_1D.plot()
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/core/project/project.py:198, in Project.__getattr__(self, item)
#     194 if item in self.meta:
#     195     # return the attribute
#     196     return self.meta[item]
# --> 198 raise AttributeError
#
# AttributeError:

# %% [markdown]
# However, this work only if the name contains no space, dot, comma, colon, etc.
# The only special character allowed is
# the underscore `_` .  If the name is not respecting this, then it is possible to use
# the following syntax (as a
# project behave as a dictionary). For example:

# %%
proj["NMR_1D"].data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 proj["NMR_1D"].data
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/core/project/project.py:160, in Project.__getitem__(self, key)
#     158 if key in self.scripts_names:
#     159     return self._scripts[key]
# --> 160 raise KeyError(f"{key}: This object name does not exist in this project.")
#
# KeyError: 'NMR_1D: This object name does not exist in this project.'

# %%
proj.NMR_1D_copy
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 proj.NMR_1D_copy
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/core/project/project.py:198, in Project.__getattr__(self, item)
#     194 if item in self.meta:
#     195     # return the attribute
#     196     return self.meta[item]
# --> 198 raise AttributeError
#
# AttributeError:

# %% [markdown]
# ## Saving and loading projects

# %%
proj
# Out:
# Project&nbsp;myNMRdata:<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;(empty&nbsp;project)

# %% [markdown]
# #### Saving

# %%
proj.save_as("NMR")
# Out:
# PosixPath('/home/runner/work/spectrochempy/spectrochempy/docs/sources/userguide/objects/project/NMR.pscp')

# %% [markdown]
# #### Loading

# %%
proj2 = scp.Project.load("NMR")

# %%
proj2
# Out:
# Project&nbsp;NMR:<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;(empty&nbsp;project)

# %%
_ = proj2.NMR_1D.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 _ = proj2.NMR_1D.plot()
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/core/project/project.py:198, in Project.__getattr__(self, item)
#     194 if item in self.meta:
#     195     # return the attribute
#     196     return self.meta[item]
# --> 198 raise AttributeError
#
# AttributeError:

# %%
proj2.NMR_1D_copy
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 proj2.NMR_1D_copy
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/core/project/project.py:198, in Project.__getattr__(self, item)
#     194 if item in self.meta:
#     195     # return the attribute
#     196     return self.meta[item]
# --> 198 raise AttributeError
#
# AttributeError:

# %%
_ = proj.NMR_1D_copy.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 _ = proj.NMR_1D_copy.plot()
#
# File ~/work/spectrochempy/spectrochempy/src/spectrochempy/core/project/project.py:198, in Project.__getattr__(self, item)
#     194 if item in self.meta:
#     195     # return the attribute
#     196     return self.meta[item]
# --> 198 raise AttributeError
#
# AttributeError:
